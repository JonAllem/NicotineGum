# %%
import pandas as pd
data = pd.read_parquet('../data/reduced/modelled_nic_gums_tweets_2022_reduced.parquet')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16940 entries, 1488067098387566592 to 1609072910571814912
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   text                        16940 non-null  object
#  1   normalized_lemmatized_text  16940 non-null  object
#  2   original_topic              16940 non-null  int64
#  3   original_topic_score        16940 non-null  float32
#  4   original_alt_topic_1        16940 non-null  int64
#  5   original_alt_topic_score_1  16940 non-null  float32
#  6   original_alt_topic_2        16940 non-null  int64
#  7   original_alt_topic_score_2  16940 non-null  float32
#  8   original_alt_topic_3        16940 non-null  int64
#  9   original_alt_topic_score_3  16940 non-null  float32
#  10  original_alt_topic_4        16940 non-null  int64
#  11  original_alt_topic_score_4  16940 non-null  float32
# ...

# %%
t_num = 3
data[data.reduced_topic == t_num].text.sample(30 if sum(data.reduced_topic==t_num) >=30 else sum(data.reduced_topic==t_num)).to_clipboard()

# %%
ORIGINAL_OTHERS_TOPICS = [1, 15, 23, 31, 32, 35, 41, 47, 48, 56]
for i, x in enumerate(data[~data.original_topic.isin(ORIGINAL_OTHERS_TOPICS)].text.sample(30)): print(i,x)
# Out:
# 0 i’m gone off that nicotine gum
# 1 To ease your discomfort, your doctor may recommend nicotine gum, a nicotine patch, or one of the other stop smoking aids.
# 2 @imagicat_ I had sucess briefly by chewing nicotine gum while vaping a nice flavour, strawberry mostly...I tried to trick myself...
# 3 Check out Nicotine Gum Rugby cinnamon sugar free 4mg https://t.co/Plbu6vNkvi #eBay via @eBay
# 4 @nudeobama nicotine gum and patches I guess
# 5 Worlds largest tobacco company BAT aims to grow annual revenue to $5 billion GBP 2025 & 50+ million using non-combustion nicotine products by 2030
#
# Vaping, patches, wads, snuffs, moist tobacco, shredded tobacco, tobacco free nicotine pouches, vape juice, nicotine gum & more
# 6 i want a vape with no nic or anything just flavor. kinda like gum. is that a thing
# 7 @c0wboybones My step mom uses nic gum! I’m proud of you man! Nicotine is a beast I’m glad you’re taking this challenge many have failed but you got the spunk to succeed!
# ...

# %%
non_others = data[~data.original_topic.isin(ORIGINAL_OTHERS_TOPICS)]
non_others.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13756 entries, 1488067098387566592 to 1609072910571814912
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   text                        13756 non-null  object
#  1   normalized_lemmatized_text  13756 non-null  object
#  2   original_topic              13756 non-null  int64
#  3   original_topic_score        13756 non-null  float32
#  4   original_alt_topic_1        13756 non-null  int64
#  5   original_alt_topic_score_1  13756 non-null  float32
#  6   original_alt_topic_2        13756 non-null  int64
#  7   original_alt_topic_score_2  13756 non-null  float32
#  8   original_alt_topic_3        13756 non-null  int64
#  9   original_alt_topic_score_3  13756 non-null  float32
#  10  original_alt_topic_4        13756 non-null  int64
#  11  original_alt_topic_score_4  13756 non-null  float32
# ...

# %%
(data.reduced_topic.value_counts() - non_others.reduced_topic.value_counts()) / data.reduced_topic.value_counts()
# Out:
# 0    0.018018
# 1    0.998367
# 2    0.115651
# 3    0.007225
# 4    0.244776
# 5    0.039886
# 6    0.013449
# 7    0.005051
# 8    0.084489
# 9    0.001486
# Name: reduced_topic, dtype: float64

# %%
original_topics = pd.read_excel('../data/topics_nic_gum_text_data_2022.xlsx')
original_topics
# Out:
#     Topic #                                           Category  \
# 0         0  Personal Experiences of using Nicotine Gum alo...
# 1         1                                             Others
# 2         2  Nicotine Gum  Twitter Promotion and Discourse ...
# 3         3  Personal Experiences of using Nicotine Gum alo...
# 4         4  Personal Experiences of using Nicotine Gum alo...
# 5         5  Nicotine Gum  Twitter Promotion and Discourse ...
# 6         6  Personal Experiences of using Nicotine Gum alo...
# 7         7  Personal Experiences of using Nicotine Gum alo...
# 8         8  Public Behavior and Perceptual Shifts around N...
# 9         9  Health Concerns, Misconceptions, & Regulatory ...
# 10       10  Comparative Discourse about Nicotine Gum and o...
# 11       11  Alternate Uses & Off-Label Applications of Nic...
# 12       12  Personal Experiences of using Nicotine Gum alo...
# 13       13  Comparative Discourse about Nicotine Gum and o...
# ...

# %%
reduced_topics = pd.read_excel('../data/reduced/reduced_topics_nic_gum_text_data_2022.xlsx')
reduced_topics
# Out:
#    topic_num                                        topic_words  \
# 0          0  nicotine, tobacco cigarette, cigarettes effect...
# 1          1  promote tobacco, stop smoking, tobacco, smokin...
# 2          2  nicotine, cigarettes effective, tobacco cigare...
# 3          3  nicotine, stop smoking, cigarettes effective, ...
# 4          4  nicotine, nicorette mg, nicotinic acid, tobacc...
# 5          5  nicotine, tobacco cigarette, tobacco, cigarett...
# 6          6  stop smoking, nicotine, smoking aid, smoke ces...
# 7          7  nicotine, stop smoking, cigarettes effective, ...
# 8          8  nicotine, promote tobacco, tobacco, tobacco ci...
# 9          9  nicotine, rugby cinnamon, rugby sugar, nicoret...
#
#    avg_topic_and_top_50_words_similarity  topic_size  \
# 0                               0.527281        5772
# 1                               0.398090        2450
# 2                               0.501254        1444
# ...

# %%
reduced_mapping = [[7, 22, 32, 14, 52, 11, 12, 50, 30, 45, 57, 17, 34, 28, 18, 23, 19, 21, 24, 29, 31, 37, 38, 33, 35, 39, 40, 41, 49, 0],
 [1],
 [56, 54, 13, 48, 53, 10],
 [27, 6],
 [15, 43, 20, 26, 42, 36, 25, 5],
 [46, 55, 8],
 [4],
 [51, 3],
 [16, 47, 9],
 [44, 2]]

# %%
original_topics[original_topics['Topic #'].isin(reduced_mapping[2])]
# Out:
#     Topic #                                           Category  \
# 10       10  Comparative Discourse about Nicotine Gum and o...
# 13       13  Comparative Discourse about Nicotine Gum and o...
# 48       48                                             Others
# 53       53  Health Concerns, Misconceptions, & Regulatory ...
# 54       54  Comparative Discourse about Nicotine Gum and o...
# 56       56                                             Others
#
#                                            Topic Name  \
# 10  Perspectives on Effectiveness, Alternatives, a...
# 13  Comparative Effectiveness of Nicotine Gum, Pat...
# 48  Nicotine Pouches vs Nicotine Gum: A Comparativ...
# 53  Regulated Nicotine Replacement Therapies and A...
# 54  Efficacy of Nicotine Gum vs. E-Cigarettes in S...
# 56  Health Advisory Discourse on Nicotine-Induced ...
#
#                                       Top Topic Words  \
# 10  nicotine, smoking aid, freenrt tobaccofree, pr...
# ...

# %%
t_num = 2
non_others[non_others.reduced_topic==t_num].text.sample(30 if sum(non_others.reduced_topic==t_num) >=30 else sum(non_others.reduced_topic==t_num)).to_clipboard()
